# %% [markdown]
# <a href="https://colab.research.google.com/github/sanathkumargampa/DSA_BS/blob/main/BS_1D_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
print("hi")
# Out:
# hi
